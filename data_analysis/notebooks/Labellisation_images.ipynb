# %% [markdown]
# # Insertion des données en base SQLite

# %%
import sqlite3

from PIL import Image, ImageDraw
import os
from os import listdir
from os.path import isfile, join
import numpy as np

# %% [markdown]
# ### Ouverture de la base de données SQLite3 "base_de_donnees"

# %% [raw]
# .open "nomdelabase".db

# %% [markdown]
# ### Ouverture des tables de ma bdd

# %% [raw]
# .tables

# %% [markdown]
# ### Création d'une colonne labels avec une requête SQL dans la table main

# %% [raw]
# # Création d'une colonne labels_images
# ALTER TABLE images ADD labels_images TEXT;
#
# # modifier une colonne dans une table SQLite
# UPDATE images set labels_images = images.id_image ||
# (SELECT name_circuit
# from circuit
# where circuit.id_circuit = images.NC_circuit) || "_" ||
# (SELECT values_throttle
# from throttle
# where throttle.id_throttle = images.NT_throttle) || "_" ||
# (SELECT values_angle
# from angle
# where angle.id_angle = images.NA_angle)

# %% [markdown]
# ### Voir les colonnes d'une table spécifique

# %% [raw]
# pragma table_info(nomDeLaTable)

# %% [raw]
# pragma table_info(main)

# %% [markdown]
# ## Création View

# %% [raw]
# CREATE VIEW ma_vue AS
# SELECT name_circuit || "_" || values_angle || "_" || values_throttle
#  from circuit , images, angle, throttle
# WHERE circuit.id_circuit = images.NC_circuit AND throttle.id_throttle = images.NT_throttle AND angle.id_angle = images.NA_angle ;

# %% [raw]
# # Afficher la VIEW
# select * from ma_vue

# %% [raw]
# # Supprimer la VIEW
# DROP VIEW ma_vue;

# %% [markdown]
# ## Création trigger

# %% [raw]
# CREATE TRIGGER my_trigger AFTER insert on images
# BEGIN
#
# UPDATE images set labels_images = images.id_image || (SELECT name_circuit from circuit where circuit.id_circuit = images.NC_circuit) || "_" || (SELECT values_throttle from throttle where throttle.id_throttle = images.NT_throttle)|| "_" ||
# (SELECT values_angle from angle where angle.id_angle = images.NA_angle) ;
#
# END;

# %% [raw]
# DROP TRIGGER my_trigger;

# %% [markdown]
# ## Création colonne labels_images avec un script Python

# %% [raw]
# connect = sqlite3.connect(db_path)
# cursor = connect.cursor()
# print("Connexion réussie à SQLite")
#
# cursor.execute("ALTER TABLE images ADD labels_images TEXT")
#
# cursor.close()
# connect.close()

# %% [markdown]
# ## Peuplement de la colonne labels_images avec un script en Python

# %% [raw]
# connect = sqlite3.connect(db_path)
# cursor = connect.cursor()
# print("Connexion réussie à SQLite")
#
# cursor.execute("UPDATE images set labels_images =
# (SELECT name_circuit || "_" || values_angle || "_" || values_throttle
# from circuit , images, angle, throttle
# WHERE circuit.id_circuit = images.NC_circuit AND throttle.id_throttle = images.NT_throttle AND angle.id_angle = images.NA_angle);")
#
# #cursor.close()
# #connect.close()

# %% [markdown]
# ### Requête de la colonne labels_image de la table images

# %%
connect = sqlite3.connect("../stockage_bdd/iaracing.db")
cursor = connect.cursor()
print("Connexion réussie à SQLite")

cursor.execute("SELECT labels_images FROM images")
row_main_2 = cursor.fetchall()

liste_labels = []
for row in row_main_2:
    print("labels :", row[0])
    liste_labels.append(row[0])

cursor.close()
connect.close()
# Out:
# Connexion réussie à SQLite
# labels : 1waveshare_0.0_0.0
# labels : 2waveshare_0.0_0.0
# labels : 3waveshare_0.0_0.3
# labels : 4waveshare_0.0_0.3
# labels : 5waveshare_0.0_0.3
# labels : 6waveshare_0.0_0.3
# labels : 7waveshare_0.0_0.3
# labels : 8waveshare_0.0_0.3
# labels : 9waveshare_0.0_0.3
# labels : 10waveshare_0.0_0.4
# labels : 11waveshare_0.0_0.4
# labels : 12waveshare_0.0_0.4
# labels : 13waveshare_0.0_0.4
# labels : 14waveshare_0.0_0.4
# labels : 15waveshare_0.0_0.4
# labels : 16waveshare_0.0_0.4
# labels : 17waveshare_0.0_0.4
# labels : 18waveshare_0.0_0.5
# labels : 19waveshare_0.0_0.5
# labels : 20waveshare_0.0_0.5
# labels : 21waveshare_0.0_0.5
# labels : 22waveshare_0.0_0.5
# labels : 23waveshare_0.0_0.5
# labels : 24waveshare_0.0_0.5
# labels : 25waveshare_0.0_0.5
# labels : 26waveshare_0.0_0.5
# labels : 27waveshare_0.0_0.5
# labels : 28waveshare_0.0_0.5
# labels : 29waveshare_0.0_0.5
# labels : 30waveshare_0.0_0.5
# labels : 31waveshare_0.0_0.5
# labels : 32waveshare_0.0_0.5
# labels : 33waveshare_0.0_0.5
# labels : 34waveshare_0.0_0.5
# labels : 35waveshare_0.0_0.5
# labels : 36waveshare_0.0_0.5
# labels : 37waveshare_0.0_0.5
# labels : 38waveshare_0.0_0.5
# labels : 39waveshare_0.0_0.5
# labels : 40waveshare_0.0_0.5
# labels : 41waveshare_0.0_0.5
# labels : 42waveshare_0.0_0.5
# labels : 43waveshare_0.0_0.5
# labels : 44waveshare_0.0_0.5
# labels : 45waveshare_0.0_0.5
# labels : 46waveshare_-0.7_0.5
# labels : 47waveshare_-0.7_0.5
# labels : 48waveshare_-1.0_0.5
# labels : 49waveshare_-1.0_0.5
# labels : 50waveshare_-1.0_0.5
# labels : 51waveshare_-1.0_0.5
# labels : 52waveshare_-1.0_0.5
# labels : 53waveshare_-1.0_0.5
# labels : 54waveshare_-1.0_0.5
# labels : 55waveshare_-1.0_0.5
# labels : 56waveshare_0.0_0.5
# labels : 57waveshare_0.0_0.5
# labels : 58waveshare_0.0_0.5
# labels : 59waveshare_0.0_0.5
# labels : 60waveshare_0.0_0.5
# labels : 61waveshare_0.0_0.5
# labels : 62waveshare_0.0_0.5
# labels : 63waveshare_0.0_0.5
# labels : 64waveshare_0.0_0.5
# labels : 65waveshare_0.0_0.5
# labels : 66waveshare_0.0_0.5
# labels : 67waveshare_-1.0_0.5
# labels : 68waveshare_-1.0_0.5
# labels : 69waveshare_-1.0_0.5
# labels : 70waveshare_-1.0_0.5
# labels : 71waveshare_-1.0_0.5
# labels : 72waveshare_-1.0_0.5
# labels : 73waveshare_-1.0_0.5
# labels : 74waveshare_-1.0_0.5
# labels : 75waveshare_-1.0_0.5
# labels : 76waveshare_-1.0_0.5
# labels : 77waveshare_-1.0_0.5
# labels : 78waveshare_-1.0_0.5
# labels : 79waveshare_-1.0_0.5
# labels : 80waveshare_-1.0_0.5
# labels : 81waveshare_-1.0_0.5
# labels : 82waveshare_-1.0_0.5
# labels : 83waveshare_-1.0_0.5
# labels : 84waveshare_-1.0_0.5
# labels : 85waveshare_-1.0_0.5
# labels : 86waveshare_-1.0_0.5
# labels : 87waveshare_-1.0_0.5
# labels : 88waveshare_-1.0_0.5
# labels : 89waveshare_-1.0_0.5
# labels : 90waveshare_-1.0_0.5
# labels : 91waveshare_-1.0_0.5
# labels : 92waveshare_-1.0_0.5
# labels : 93waveshare_-1.0_0.5
# labels : 94waveshare_0.0_0.5
# labels : 95waveshare_0.0_0.5
# labels : 96waveshare_0.0_0.5
# labels : 97waveshare_0.0_0.5
# labels : 98waveshare_0.0_0.5
# labels : 99waveshare_0.0_0.5
# labels : 100waveshare_0.0_0.5
# labels : 101waveshare_0.0_0.5
# labels : 102waveshare_-1.0_0.5
# labels : 103waveshare_-1.0_0.5
# labels : 104waveshare_-1.0_0.5
# labels : 105waveshare_-1.0_0.5
# labels : 106waveshare_-1.0_0.5
# labels : 107waveshare_-1.0_0.5
# labels : 108waveshare_-1.0_0.5
# labels : 109waveshare_-1.0_0.5
# labels : 110waveshare_-1.0_0.5
# labels : 111waveshare_-1.0_0.5
# labels : 112waveshare_-1.0_0.5
# labels : 113waveshare_-1.0_0.5
# labels : 114waveshare_-1.0_0.5
# labels : 115waveshare_-1.0_0.5
# labels : 116waveshare_-1.0_0.5
# labels : 117waveshare_-1.0_0.5
# labels : 118waveshare_-1.0_0.5
# labels : 119waveshare_-1.0_0.5
# labels : 120waveshare_-1.0_0.5
# labels : 121waveshare_-1.0_0.5
# labels : 122waveshare_-1.0_0.5
# labels : 123waveshare_-1.0_0.5
# labels : 124waveshare_-1.0_0.5
# labels : 125waveshare_-1.0_0.5
# labels : 126waveshare_-1.0_0.5
# labels : 127waveshare_0.0_0.5
# labels : 128waveshare_0.0_0.5
# labels : 129waveshare_0.0_0.5
# labels : 130waveshare_0.0_0.5
# labels : 131waveshare_0.0_0.5
# labels : 132waveshare_0.0_0.5
# labels : 133waveshare_0.0_0.5
# labels : 134waveshare_0.0_0.5
# labels : 135waveshare_0.0_0.5
# labels : 136waveshare_0.0_0.5
# labels : 137waveshare_0.0_0.5
# labels : 138waveshare_0.0_0.5
# labels : 139waveshare_0.0_0.5
# labels : 140waveshare_0.0_0.5
# labels : 141waveshare_0.0_0.5
# labels : 142waveshare_0.0_0.5
# labels : 143waveshare_0.0_0.5
# labels : 144waveshare_0.0_0.5
# labels : 145waveshare_0.0_0.5
# labels : 146waveshare_0.0_0.5
# labels : 147waveshare_0.0_0.5
# labels : 148waveshare_0.0_0.5
# labels : 149waveshare_0.0_0.5
# labels : 150waveshare_0.0_0.5
# labels : 151waveshare_0.0_0.5
# labels : 152waveshare_0.0_0.5
# labels : 153waveshare_0.0_0.5
# labels : 154waveshare_-1.0_0.5
# labels : 155waveshare_-1.0_0.5
# labels : 156waveshare_-1.0_0.5
# labels : 157waveshare_-1.0_0.5
# labels : 158waveshare_-1.0_0.5
# labels : 159waveshare_-1.0_0.5
# labels : 160waveshare_-1.0_0.5
# labels : 161waveshare_-1.0_0.5
# labels : 162waveshare_-1.0_0.5
# labels : 163waveshare_-1.0_0.5
# labels : 164waveshare_-1.0_0.5
# labels : 165waveshare_-1.0_0.5
# labels : 166waveshare_-1.0_0.5
# labels : 167waveshare_-1.0_0.5
# labels : 168waveshare_-1.0_0.5
# labels : 169waveshare_-1.0_0.5
# labels : 170waveshare_-1.0_0.5
# labels : 171waveshare_-1.0_0.5
# labels : 172waveshare_-1.0_0.5
# labels : 173waveshare_-1.0_0.5
# labels : 174waveshare_-1.0_0.5
# labels : 175waveshare_0.0_0.5
# labels : 176waveshare_0.0_0.5
# labels : 177waveshare_0.0_0.5
# labels : 178waveshare_0.0_0.5
# labels : 179waveshare_-1.0_0.5
# labels : 180waveshare_-1.0_0.5
# labels : 181waveshare_-1.0_0.5
# labels : 182waveshare_-1.0_0.5
# labels : 183waveshare_-1.0_0.5
# labels : 184waveshare_-1.0_0.5
# labels : 185waveshare_-1.0_0.5
# labels : 186waveshare_-1.0_0.5
# labels : 187waveshare_-1.0_0.5
# labels : 188waveshare_-1.0_0.5
# labels : 189waveshare_-1.0_0.5
# labels : 190waveshare_-1.0_0.5
# labels : 191waveshare_-1.0_0.5
# labels : 192waveshare_-1.0_0.5
# labels : 193waveshare_-1.0_0.5
# labels : 194waveshare_-1.0_0.5
# labels : 195waveshare_-1.0_0.5
# labels : 196waveshare_-1.0_0.5
# labels : 197waveshare_-1.0_0.5
# labels : 198waveshare_-1.0_0.5
# labels : 199waveshare_-1.0_0.5
# labels : 200waveshare_-1.0_0.5
# labels : 201waveshare_-1.0_0.5
# labels : 202waveshare_-0.8_0.5
# labels : 203waveshare_-0.8_0.5
# labels : 204waveshare_0.0_0.5
# labels : 205waveshare_0.0_0.5
# labels : 206waveshare_0.0_0.5
# labels : 207waveshare_0.0_0.5
# labels : 208waveshare_0.0_0.5
# labels : 209waveshare_0.0_0.5
# labels : 210waveshare_0.0_0.5
# labels : 211waveshare_0.0_0.5
# labels : 212waveshare_0.0_0.5
# labels : 213waveshare_1.0_0.5
# labels : 214waveshare_1.0_0.5
# labels : 215waveshare_1.0_0.5
# labels : 216waveshare_0.0_0.5
# labels : 217waveshare_0.0_0.5
# labels : 218waveshare_0.0_0.5
# labels : 219waveshare_0.0_0.5
# labels : 220waveshare_0.0_0.5
# labels : 221waveshare_0.0_0.5
# labels : 222waveshare_0.0_0.5
# labels : 223waveshare_0.0_0.5
# labels : 224waveshare_0.0_0.5
# labels : 225waveshare_0.0_0.5
# labels : 226waveshare_0.0_0.5
# labels : 227waveshare_0.0_0.5
# labels : 228waveshare_0.0_0.5
# labels : 229waveshare_0.0_0.5
# labels : 230waveshare_0.0_0.5
# labels : 231waveshare_-1.0_0.5
# labels : 232waveshare_-1.0_0.5
# labels : 233waveshare_-1.0_0.5
# labels : 234waveshare_-1.0_0.5
# labels : 235waveshare_-1.0_0.5
# labels : 236waveshare_-1.0_0.5
# labels : 237waveshare_-1.0_0.5
# labels : 238waveshare_-1.0_0.5
# labels : 239waveshare_-1.0_0.5
# labels : 240waveshare_0.0_0.8
# labels : 241waveshare_0.0_1.0
# labels : 242waveshare_0.0_1.0
# labels : 243waveshare_0.0_1.0
# labels : 244waveshare_0.0_1.0
# labels : 245waveshare_0.0_1.0
# labels : 246waveshare_0.0_1.0
# labels : 247waveshare_0.0_1.0
# labels : 248waveshare_0.0_1.0
# labels : 249waveshare_0.0_1.0
# labels : 250waveshare_0.0_1.0
# labels : 251waveshare_0.0_1.0
# labels : 252waveshare_0.0_1.0
# labels : 253waveshare_0.0_0.4
# labels : 254waveshare_0.0_0.4
# labels : 255waveshare_0.0_0.4
# labels : 256waveshare_0.0_0.4
# labels : 257waveshare_0.0_0.4
# labels : 258waveshare_0.0_0.4
# labels : 259waveshare_0.0_0.4
# labels : 260waveshare_0.0_0.4
# labels : 261waveshare_0.0_0.4
# labels : 262waveshare_0.0_0.4
# labels : 263waveshare_0.0_0.4
# labels : 264waveshare_-0.2_0.4
# labels : 265waveshare_-1.0_0.4
# labels : 266waveshare_-1.0_0.4
# labels : 267waveshare_-1.0_0.4
# labels : 268waveshare_-1.0_0.4
# labels : 269waveshare_-1.0_0.4
# labels : 270waveshare_-1.0_0.4
# labels : 271waveshare_-1.0_0.4
# labels : 272waveshare_-1.0_0.4
# labels : 273waveshare_-1.0_0.4
# labels : 274waveshare_-1.0_0.4
# labels : 275waveshare_-1.0_0.4
# labels : 276waveshare_-1.0_0.4
# labels : 277waveshare_0.0_0.4
# labels : 278waveshare_0.0_0.4
# labels : 279waveshare_0.0_0.4
# labels : 280waveshare_0.0_0.4
# labels : 281waveshare_0.0_0.4
# labels : 282waveshare_0.0_0.4
# labels : 283waveshare_0.0_0.4
# labels : 284waveshare_0.0_0.4
# labels : 285waveshare_-1.0_0.4
# labels : 286waveshare_-1.0_0.4
# labels : 287waveshare_-1.0_0.4
# labels : 288waveshare_-1.0_0.4
# labels : 289waveshare_-1.0_0.4
# labels : 290waveshare_-1.0_0.4
# labels : 291waveshare_-1.0_0.4
# labels : 292waveshare_-1.0_0.4
# labels : 293waveshare_-1.0_0.4
# labels : 294waveshare_-1.0_0.4
# labels : 295waveshare_-1.0_0.4
# labels : 296waveshare_-1.0_0.4
# labels : 297waveshare_-1.0_0.4
# labels : 298waveshare_-1.0_0.4
# labels : 299waveshare_-1.0_0.4
# labels : 300waveshare_-1.0_0.4
# labels : 301waveshare_-1.0_0.4
# labels : 302waveshare_-1.0_0.4
# labels : 303waveshare_-1.0_0.4
# labels : 304waveshare_-1.0_0.4
# labels : 305waveshare_-1.0_0.4
# labels : 306waveshare_-1.0_0.4
# labels : 307waveshare_-1.0_0.4
# labels : 308waveshare_-1.0_0.4
# labels : 309waveshare_-1.0_0.4
# labels : 310waveshare_-1.0_0.4
# labels : 311waveshare_-1.0_0.4
# labels : 312waveshare_-1.0_0.4
# labels : 313waveshare_-1.0_0.4
# labels : 314waveshare_0.0_0.4
# labels : 315waveshare_0.0_0.4
# labels : 316waveshare_0.0_0.4
# labels : 317waveshare_0.0_0.4
# labels : 318waveshare_0.0_0.4
# labels : 319waveshare_0.0_0.4
# labels : 320waveshare_0.0_0.4
# labels : 321waveshare_0.0_0.4
# labels : 322waveshare_0.0_0.4
# labels : 323waveshare_-0.4_0.4
# labels : 324waveshare_-0.4_0.4
# labels : 325waveshare_-1.0_0.4
# labels : 326waveshare_-1.0_0.4
# labels : 327waveshare_-1.0_0.4
# labels : 328waveshare_-1.0_0.4
# labels : 329waveshare_-1.0_0.4
# labels : 330waveshare_-1.0_0.4
# labels : 331waveshare_0.0_0.4
# labels : 332waveshare_0.0_0.4
# labels : 333waveshare_0.0_0.4
# labels : 334waveshare_0.0_0.4
# labels : 335waveshare_0.0_0.4
# labels : 336waveshare_0.0_0.4
# labels : 337waveshare_0.0_0.4
# labels : 338waveshare_0.0_0.4
# labels : 339waveshare_0.0_0.4
# labels : 340waveshare_0.0_0.4
# labels : 341waveshare_0.0_0.4
# labels : 342waveshare_0.0_0.4
# labels : 343waveshare_0.0_0.4
# labels : 344waveshare_0.0_0.4
# labels : 345waveshare_0.0_0.4
# labels : 346waveshare_0.0_0.4
# labels : 347waveshare_0.0_0.4
# labels : 348waveshare_0.0_0.4
# labels : 349waveshare_0.0_0.4
# labels : 350waveshare_0.0_0.4
# labels : 351waveshare_0.0_0.4
# labels : 352waveshare_-1.0_0.4
# labels : 353waveshare_-1.0_0.4
# labels : 354waveshare_-1.0_0.4
# labels : 355waveshare_-1.0_0.4
# labels : 356waveshare_-1.0_0.4
# labels : 357waveshare_-1.0_0.4
# labels : 358waveshare_-1.0_0.4
# labels : 359waveshare_-1.0_0.4
# labels : 360waveshare_-1.0_0.4
# labels : 361waveshare_-1.0_0.4
# labels : 362waveshare_-1.0_0.4
# labels : 363waveshare_-1.0_0.4
# labels : 364waveshare_-1.0_0.4
# labels : 365waveshare_-1.0_0.4
# labels : 366waveshare_-1.0_0.4
# labels : 367waveshare_-1.0_0.4
# labels : 368waveshare_-1.0_0.4
# labels : 369waveshare_-1.0_0.4
# labels : 370waveshare_-1.0_0.4
# labels : 371waveshare_-1.0_0.4
# labels : 372waveshare_-1.0_0.4
# labels : 373waveshare_-1.0_0.4
# labels : 374waveshare_-1.0_0.4
# labels : 375waveshare_-1.0_0.4
# labels : 376waveshare_0.0_0.4
# labels : 377waveshare_0.0_0.4
# labels : 378waveshare_0.0_0.4
# labels : 379waveshare_0.0_0.4
# labels : 380waveshare_0.0_0.4
# labels : 381waveshare_-1.0_0.4
# labels : 382waveshare_-1.0_0.4
# labels : 383waveshare_-1.0_0.4
# labels : 384waveshare_-1.0_0.4
# labels : 385waveshare_-1.0_0.4
# labels : 386waveshare_-1.0_0.4
# labels : 387waveshare_-1.0_0.4
# labels : 388waveshare_-1.0_0.4
# labels : 389waveshare_-1.0_0.4
# labels : 390waveshare_-1.0_0.4
# labels : 391waveshare_-1.0_0.4
# labels : 392waveshare_-1.0_0.4
# labels : 393waveshare_-0.7_0.4
# labels : 394waveshare_0.0_0.4
# labels : 395waveshare_0.0_0.4
# labels : 396waveshare_0.0_0.4
# labels : 397waveshare_0.0_0.4
# labels : 398waveshare_0.0_0.4
# labels : 399waveshare_0.0_0.4
# labels : 400waveshare_0.0_0.4
# labels : 401waveshare_0.0_0.4
# labels : 402waveshare_0.0_0.4
# labels : 403waveshare_0.0_0.4
# labels : 404waveshare_-1.0_0.4
# labels : 405waveshare_-1.0_0.4
# labels : 406waveshare_-1.0_0.4
# labels : 407waveshare_-1.0_0.4
# labels : 408waveshare_-1.0_0.4
# labels : 409waveshare_-1.0_0.4
# labels : 410waveshare_-1.0_0.4
# labels : 411waveshare_-1.0_0.4
# labels : 412waveshare_-1.0_0.4
# labels : 413waveshare_-1.0_0.4
# labels : 414waveshare_-1.0_0.4
# labels : 415waveshare_0.0_0.4
# labels : 416waveshare_0.0_0.4
# labels : 417waveshare_0.0_0.4
# labels : 418waveshare_0.0_0.4
# labels : 419waveshare_0.0_0.4
# labels : 420waveshare_0.0_0.4
# labels : 421waveshare_0.0_0.4
# labels : 422waveshare_0.0_0.4
# labels : 423waveshare_0.0_0.4
# labels : 424waveshare_0.0_0.4
# labels : 425waveshare_-0.8_0.4
# labels : 426waveshare_-1.0_0.4
# labels : 427waveshare_-1.0_0.4
# labels : 428waveshare_-1.0_0.4
# labels : 429waveshare_-1.0_0.4
# labels : 430waveshare_-1.0_0.4
# labels : 431waveshare_-1.0_0.4
# labels : 432waveshare_0.0_0.4
# labels : 433waveshare_0.0_0.4
# labels : 434waveshare_0.0_0.4
# labels : 435waveshare_0.0_0.4
# labels : 436waveshare_0.0_0.4
# labels : 437waveshare_0.0_0.4
# labels : 438waveshare_0.0_0.4
# labels : 439waveshare_0.0_0.4
# labels : 440waveshare_0.0_0.4
# labels : 441waveshare_0.0_0.4
# labels : 442waveshare_0.0_0.4
# labels : 443waveshare_0.0_0.4
# labels : 444waveshare_-1.0_0.4
# labels : 445waveshare_-1.0_0.4
# labels : 446waveshare_-1.0_0.4
# labels : 447waveshare_-1.0_0.4
# labels : 448waveshare_-1.0_0.4
# labels : 449waveshare_-1.0_0.4
# labels : 450waveshare_-1.0_0.4
# labels : 451waveshare_-1.0_0.4
# labels : 452waveshare_-1.0_0.4
# labels : 453waveshare_-1.0_0.4
# labels : 454waveshare_-1.0_0.4
# labels : 455waveshare_-1.0_0.4
# labels : 456waveshare_-1.0_0.4
# labels : 457waveshare_-1.0_0.4
# labels : 458waveshare_-1.0_0.4
# labels : 459waveshare_-1.0_0.4
# labels : 460waveshare_-1.0_0.4
# labels : 461waveshare_-1.0_0.4
# labels : 462waveshare_-1.0_0.4
# labels : 463waveshare_-1.0_0.4
# labels : 464waveshare_-1.0_0.4
# labels : 465waveshare_-1.0_0.4
# labels : 466waveshare_-1.0_0.4
# labels : 467waveshare_-1.0_0.4
# labels : 468waveshare_-1.0_0.4
# labels : 469waveshare_-1.0_0.4
# labels : 470waveshare_-1.0_0.4
# labels : 471waveshare_0.0_0.4
# labels : 472waveshare_0.0_0.4
# labels : 473waveshare_0.0_0.4
# labels : 474waveshare_0.0_0.4
# labels : 475waveshare_0.0_0.4
# labels : 476waveshare_0.0_0.4
# labels : 477waveshare_0.0_0.4
# labels : 478waveshare_0.0_0.4
# labels : 479waveshare_-1.0_0.4
# labels : 480waveshare_-1.0_0.4
# labels : 481waveshare_-1.0_0.4
# labels : 482waveshare_-1.0_0.4
# labels : 483waveshare_-1.0_0.4
# labels : 484waveshare_-1.0_0.4
# labels : 485waveshare_-1.0_0.4
# labels : 486waveshare_-1.0_0.4
# labels : 487waveshare_-1.0_0.4
# labels : 488waveshare_-1.0_0.4
# labels : 489waveshare_-1.0_0.4
# labels : 490waveshare_-1.0_0.4
# labels : 491waveshare_-1.0_0.4
# labels : 492waveshare_-1.0_0.4
# labels : 493waveshare_0.0_0.4
# labels : 494waveshare_0.0_0.4
# labels : 495waveshare_0.0_0.4
# labels : 496waveshare_0.0_0.4
# labels : 497waveshare_0.0_0.4
# labels : 498waveshare_0.0_0.4
# labels : 499waveshare_0.0_0.4
# labels : 500waveshare_0.0_0.4
# labels : 501waveshare_0.0_0.4
# labels : 502waveshare_0.0_0.4
# labels : 503waveshare_0.0_0.4
# labels : 504waveshare_0.0_0.4
# labels : 505waveshare_-1.0_0.4
# labels : 506waveshare_-1.0_0.4
# labels : 507waveshare_-1.0_0.4
# labels : 508waveshare_-1.0_0.4
# labels : 509waveshare_-1.0_0.4
# labels : 510waveshare_0.0_0.4
# labels : 511waveshare_0.0_0.4
# labels : 512waveshare_0.0_0.4
# labels : 513waveshare_0.0_0.4
# labels : 514waveshare_0.0_0.4
# labels : 515waveshare_0.0_0.4
# labels : 516waveshare_0.0_0.4
# labels : 517waveshare_0.0_0.4
# labels : 518waveshare_0.0_0.4
# labels : 519waveshare_0.0_0.4
# labels : 520waveshare_0.0_0.4
# labels : 521waveshare_0.0_0.4
# labels : 522waveshare_0.0_0.4
# labels : 523waveshare_0.0_0.4
# labels : 524waveshare_-0.6_0.4
# labels : 525waveshare_-0.6_0.4
# labels : 526waveshare_-1.0_0.4
# labels : 527waveshare_-1.0_0.4
# labels : 528waveshare_-1.0_0.4
# labels : 529waveshare_-1.0_0.4
# labels : 530waveshare_-1.0_0.4
# labels : 531waveshare_-1.0_0.4
# labels : 532waveshare_-1.0_0.4
# labels : 533waveshare_-1.0_0.4
# labels : 534waveshare_-1.0_0.4
# labels : 535waveshare_-1.0_0.4
# labels : 536waveshare_-1.0_0.4
# labels : 537waveshare_-1.0_0.4
# labels : 538waveshare_-1.0_0.4
# labels : 539waveshare_-1.0_0.4
# labels : 540waveshare_-1.0_0.4
# labels : 541waveshare_-1.0_0.4
# labels : 542waveshare_-1.0_0.4
# labels : 543waveshare_-1.0_0.4
# labels : 544waveshare_-1.0_0.4
# labels : 545waveshare_-1.0_0.4
# labels : 546waveshare_-1.0_0.4
# labels : 547waveshare_-1.0_0.4
# labels : 548waveshare_-1.0_0.4
# labels : 549waveshare_-1.0_0.4
# labels : 550waveshare_-1.0_0.4
# labels : 551waveshare_-1.0_0.4
# labels : 552waveshare_-1.0_0.4
# labels : 553waveshare_-1.0_0.4
# labels : 554waveshare_-1.0_0.4
# labels : 555waveshare_-1.0_0.4
# labels : 556waveshare_-1.0_0.4
# labels : 557waveshare_-1.0_0.4
# labels : 558waveshare_-1.0_0.4
# labels : 559waveshare_0.0_0.4
# labels : 560waveshare_0.0_0.4
# labels : 561waveshare_0.0_0.4
# labels : 562waveshare_0.0_0.4
# labels : 563waveshare_0.0_0.4
# labels : 564waveshare_0.0_0.4
# labels : 565waveshare_0.0_0.4
# labels : 566waveshare_0.0_0.4
# labels : 567waveshare_0.0_0.4
# labels : 568waveshare_0.0_0.4
# labels : 569waveshare_-1.0_0.4
# labels : 570waveshare_-1.0_0.4
# labels : 571waveshare_-1.0_0.4
# labels : 572waveshare_-1.0_0.4
# labels : 573waveshare_-1.0_0.4
# labels : 574waveshare_-1.0_0.4
# labels : 575waveshare_-1.0_0.4
# labels : 576waveshare_-1.0_0.4
# labels : 577waveshare_-1.0_0.4
# labels : 578waveshare_0.0_0.4
# labels : 579waveshare_0.0_0.4
# labels : 580waveshare_0.0_0.4
# labels : 581waveshare_0.0_0.4
# labels : 582waveshare_0.0_0.4
# labels : 583waveshare_0.0_0.4
# labels : 584waveshare_0.0_0.4
# labels : 585waveshare_0.0_0.4
# labels : 586waveshare_0.0_0.4
# labels : 587waveshare_0.0_0.4
# labels : 588waveshare_0.0_0.4
# labels : 589waveshare_0.0_0.4
# labels : 590waveshare_0.0_0.4
# labels : 591waveshare_0.0_0.4
# labels : 592waveshare_0.0_0.4
# labels : 593waveshare_0.0_0.4
# labels : 594waveshare_0.0_0.4
# labels : 595waveshare_0.0_0.4
# labels : 596waveshare_0.0_0.4
# labels : 597waveshare_0.0_0.4
# labels : 598waveshare_0.0_0.4
# labels : 599waveshare_0.0_0.4
# labels : 600waveshare_0.0_0.4
# labels : 601waveshare_0.0_0.4
# labels : 602waveshare_-1.0_0.4
# labels : 603waveshare_-1.0_0.4
# labels : 604waveshare_-1.0_0.4
# labels : 605waveshare_-1.0_0.4
# labels : 606waveshare_-1.0_0.4
# labels : 607waveshare_-1.0_0.4
# labels : 608waveshare_-1.0_0.4
# labels : 609waveshare_-1.0_0.4
# labels : 610waveshare_-1.0_0.4
# labels : 611waveshare_-1.0_0.4
# labels : 612waveshare_-1.0_0.4
# labels : 613waveshare_-1.0_0.4
# labels : 614waveshare_-1.0_0.4
# labels : 615waveshare_-1.0_0.4
# labels : 616waveshare_-1.0_0.4
# labels : 617waveshare_-1.0_0.4
# labels : 618waveshare_-1.0_0.4
# labels : 619waveshare_-1.0_0.4
# labels : 620waveshare_-1.0_0.4
# labels : 621waveshare_-1.0_0.4
# labels : 622waveshare_-1.0_0.4
# labels : 623waveshare_-1.0_0.4
# labels : 624waveshare_-1.0_0.4
# labels : 625waveshare_-1.0_0.4
# labels : 626waveshare_-1.0_0.4
# labels : 627waveshare_-1.0_0.4
# labels : 628waveshare_-1.0_0.4
# labels : 629waveshare_-1.0_0.4
# labels : 630waveshare_-1.0_0.4
# labels : 631waveshare_-1.0_0.4
# labels : 632waveshare_-1.0_0.4
# labels : 633waveshare_-1.0_0.4
# labels : 634waveshare_-1.0_0.4
# labels : 635waveshare_-1.0_0.4
# labels : 636waveshare_-1.0_0.4
# labels : 637waveshare_-1.0_0.4
# labels : 638waveshare_-1.0_0.4
# labels : 639waveshare_0.0_0.4
# labels : 640waveshare_0.0_0.4
# labels : 641waveshare_0.0_0.4
# labels : 642waveshare_0.0_0.4
# labels : 643waveshare_0.0_0.4
# labels : 644waveshare_0.0_0.4
# labels : 645waveshare_0.0_0.4
# labels : 646waveshare_0.0_0.4
# labels : 647waveshare_-1.0_0.4
# labels : 648waveshare_-1.0_0.4
# labels : 649waveshare_-1.0_0.4
# labels : 650waveshare_-1.0_0.4
# labels : 651waveshare_-1.0_0.4
# labels : 652waveshare_-1.0_0.4
# labels : 653waveshare_-1.0_0.4
# labels : 654waveshare_-1.0_0.4
# labels : 655waveshare_-1.0_0.4
# labels : 656waveshare_-1.0_0.4
# labels : 657waveshare_0.0_0.4
# labels : 658waveshare_0.0_0.4
# labels : 659waveshare_0.0_0.4
# labels : 660waveshare_0.0_0.4
# labels : 661waveshare_0.0_0.4
# labels : 662waveshare_0.0_0.4
# labels : 663waveshare_0.0_0.4
# labels : 664waveshare_0.0_0.4
# labels : 665waveshare_0.0_0.4
# labels : 666waveshare_0.0_0.4
# labels : 667waveshare_0.0_0.4
# labels : 668waveshare_0.0_0.4
# labels : 669waveshare_0.0_0.4
# labels : 670waveshare_0.0_0.4
# labels : 671waveshare_0.0_0.4
# labels : 672waveshare_0.0_0.4
# labels : 673waveshare_0.0_0.4
# labels : 674waveshare_0.0_0.4
# labels : 675waveshare_0.0_0.4
# labels : 676waveshare_0.0_0.4
# labels : 677waveshare_0.0_0.4
# labels : 678waveshare_0.0_0.4
# labels : 679waveshare_-1.0_0.4
# labels : 680waveshare_-1.0_0.4
# labels : 681waveshare_-1.0_0.4
# labels : 682waveshare_-1.0_0.4
# labels : 683waveshare_-1.0_0.4
# labels : 684waveshare_-1.0_0.4
# labels : 685waveshare_-1.0_0.4
# labels : 686waveshare_-1.0_0.4
# labels : 687waveshare_-1.0_0.4
# labels : 688waveshare_-1.0_0.4
# labels : 689waveshare_-1.0_0.4
# labels : 690waveshare_-1.0_0.4
# labels : 691waveshare_-1.0_0.4
# labels : 692waveshare_-1.0_0.4
# labels : 693waveshare_-1.0_0.4
# labels : 694waveshare_-1.0_0.4
# labels : 695waveshare_-1.0_0.4
# labels : 696waveshare_-1.0_0.4
# labels : 697waveshare_-1.0_0.4
# labels : 698waveshare_-1.0_0.4
# labels : 699waveshare_-1.0_0.4
# labels : 700waveshare_0.0_0.4
# labels : 701waveshare_0.0_0.4
# labels : 702waveshare_0.0_0.4
# labels : 703waveshare_0.0_0.4
# labels : 704waveshare_0.0_0.4
# labels : 705waveshare_0.0_0.4
# labels : 706waveshare_0.0_0.4
# labels : 707waveshare_-1.0_0.4
# labels : 708waveshare_-1.0_0.4
# labels : 709waveshare_-1.0_0.4
# labels : 710waveshare_-1.0_0.4
# labels : 711waveshare_-1.0_0.4
# labels : 712waveshare_-1.0_0.4
# labels : 713waveshare_-1.0_0.4
# labels : 714waveshare_-1.0_0.4
# labels : 715waveshare_-1.0_0.4
# labels : 716waveshare_-1.0_0.4
# labels : 717waveshare_-1.0_0.4
# labels : 718waveshare_-1.0_0.4
# labels : 719waveshare_-1.0_0.4
# labels : 720waveshare_-1.0_0.4
# labels : 721waveshare_-1.0_0.4
# labels : 722waveshare_-1.0_0.4
# labels : 723waveshare_-1.0_0.4
# labels : 724waveshare_-1.0_0.4
# labels : 725waveshare_-1.0_0.4
# labels : 726waveshare_0.0_0.4
# labels : 727waveshare_0.0_0.4
# labels : 728waveshare_0.0_0.4
# labels : 729waveshare_0.0_0.4
# labels : 730waveshare_0.0_0.4
# labels : 731waveshare_0.0_0.4
# labels : 732waveshare_0.0_0.4
# labels : 733waveshare_0.0_0.4
# labels : 734waveshare_0.0_0.4
# labels : 735waveshare_0.0_0.4
# labels : 736waveshare_-1.0_0.4
# labels : 737waveshare_-1.0_0.4
# labels : 738waveshare_-1.0_0.4
# labels : 739waveshare_-1.0_0.4
# labels : 740waveshare_-1.0_0.4
# labels : 741waveshare_-1.0_0.4
# labels : 742waveshare_0.0_0.4
# labels : 743waveshare_0.0_0.4
# labels : 744waveshare_0.0_0.4
# labels : 745waveshare_0.0_0.4
# labels : 746waveshare_0.0_0.4
# labels : 747waveshare_0.0_0.4
# labels : 748waveshare_0.0_0.4
# labels : 749waveshare_0.0_0.4
# labels : 750waveshare_0.0_0.4
# labels : 751waveshare_0.0_0.4
# labels : 752waveshare_-1.0_0.4
# labels : 753waveshare_-1.0_0.4
# labels : 754waveshare_-1.0_0.4
# labels : 755waveshare_-1.0_0.4
# labels : 756waveshare_-1.0_0.4
# labels : 757waveshare_-1.0_0.4
# labels : 758waveshare_-1.0_0.4
# labels : 759waveshare_-1.0_0.4
# labels : 760waveshare_-0.5_0.4
# labels : 761waveshare_0.0_0.4
# labels : 762waveshare_0.0_0.4
# labels : 763waveshare_0.0_0.4
# labels : 764waveshare_0.0_0.4
# labels : 765waveshare_0.0_0.4
# labels : 766waveshare_0.0_0.4
# labels : 767waveshare_0.0_0.4
# labels : 768waveshare_-1.0_0.4
# labels : 769waveshare_-1.0_0.4
# labels : 770waveshare_-1.0_0.4
# labels : 771waveshare_-1.0_0.4
# labels : 772waveshare_-1.0_0.4
# labels : 773waveshare_-1.0_0.4
# labels : 774waveshare_-1.0_0.4
# labels : 775waveshare_-1.0_0.4
# labels : 776waveshare_-1.0_0.4
# labels : 777waveshare_-1.0_0.4
# labels : 778waveshare_-1.0_0.4
# labels : 779waveshare_-1.0_0.4
# labels : 780waveshare_-1.0_0.4
# labels : 781waveshare_-1.0_0.4
# labels : 782waveshare_-1.0_0.4
# labels : 783waveshare_-1.0_0.4
# labels : 784waveshare_-1.0_0.4
# labels : 785waveshare_-1.0_0.4
# labels : 786waveshare_-1.0_0.4
# labels : 787waveshare_-1.0_0.4
# labels : 788waveshare_-1.0_0.4
# labels : 789waveshare_-1.0_0.4
# labels : 790waveshare_-1.0_0.4
# labels : 791waveshare_-1.0_0.4
# labels : 792waveshare_-1.0_0.4
# labels : 793waveshare_-0.8_0.4
# labels : 794waveshare_-0.8_0.4
# labels : 795waveshare_0.0_0.4
# labels : 796waveshare_0.0_0.4
# labels : 797waveshare_0.0_0.4
# labels : 798waveshare_0.0_0.4
# labels : 799waveshare_0.0_0.4
# labels : 800waveshare_0.0_0.4
# labels : 801waveshare_-1.0_0.4
# labels : 802waveshare_-1.0_0.4
# labels : 803waveshare_-1.0_0.4
# labels : 804waveshare_-1.0_0.4
# labels : 805waveshare_-1.0_0.4
# labels : 806waveshare_-1.0_0.4
# labels : 807waveshare_-1.0_0.4
# labels : 808waveshare_-1.0_0.4
# labels : 809waveshare_-1.0_0.4
# labels : 810waveshare_-1.0_0.4
# labels : 811waveshare_-1.0_0.4
# labels : 812waveshare_-1.0_0.4
# labels : 813waveshare_-1.0_0.4
# labels : 814waveshare_-1.0_0.4
# labels : 815waveshare_-1.0_0.4
# labels : 816waveshare_0.0_0.4
# labels : 817waveshare_0.0_0.4
# labels : 818waveshare_0.0_0.4
# labels : 819waveshare_0.0_0.4
# labels : 820waveshare_0.0_0.4
# labels : 821waveshare_0.0_0.4
# labels : 822waveshare_0.0_0.4
# labels : 823waveshare_0.0_0.4
# labels : 824waveshare_0.0_0.4
# labels : 825waveshare_0.0_0.4
# labels : 826waveshare_0.0_0.4
# labels : 827waveshare_0.0_0.4
# labels : 828waveshare_0.0_0.4
# labels : 829waveshare_0.0_0.4
# labels : 830waveshare_0.0_0.4
# labels : 831waveshare_0.0_0.4
# labels : 832waveshare_0.0_0.4
# labels : 833waveshare_0.0_0.4
# labels : 834waveshare_0.0_0.4
# labels : 835waveshare_0.0_0.4
# labels : 836waveshare_0.0_0.4
# labels : 837waveshare_0.0_0.4
# labels : 838waveshare_0.0_0.4
# labels : 839waveshare_0.0_0.4
# labels : 840waveshare_0.0_0.4
# labels : 841waveshare_0.0_0.4
# labels : 842waveshare_0.0_0.4
# labels : 843waveshare_-1.0_0.4
# labels : 844waveshare_-1.0_0.4
# labels : 845waveshare_-1.0_0.4
# labels : 846waveshare_-1.0_0.4
# labels : 847waveshare_-1.0_0.4
# labels : 848waveshare_-1.0_0.4
# labels : 849waveshare_-1.0_0.4
# labels : 850waveshare_-1.0_0.4
# labels : 851waveshare_-1.0_0.4
# labels : 852waveshare_-1.0_0.4
# labels : 853waveshare_-1.0_0.4
# labels : 854waveshare_-1.0_0.4
# labels : 855waveshare_-1.0_0.4
# labels : 856waveshare_-1.0_0.4
# labels : 857waveshare_-1.0_0.4
# labels : 858waveshare_-1.0_0.4
# labels : 859waveshare_-1.0_0.4
# labels : 860waveshare_-1.0_0.4
# labels : 861waveshare_-1.0_0.4
# labels : 862waveshare_-1.0_0.4
# labels : 863waveshare_-1.0_0.4
# labels : 864waveshare_-1.0_0.4
# labels : 865waveshare_-1.0_0.4
# labels : 866waveshare_-1.0_0.4
# labels : 867waveshare_-1.0_0.4
# labels : 868waveshare_-1.0_0.4
# labels : 869waveshare_-1.0_0.4
# labels : 870waveshare_-1.0_0.4
# labels : 871waveshare_-1.0_0.4
# labels : 872waveshare_-1.0_0.4
# labels : 873waveshare_-1.0_0.4
# labels : 874waveshare_-1.0_0.4
# labels : 875waveshare_-1.0_0.4
# labels : 876waveshare_-1.0_0.4
# labels : 877waveshare_-1.0_0.4
# labels : 878waveshare_-1.0_0.4
# labels : 879waveshare_-1.0_0.4
# labels : 880waveshare_-1.0_0.4
# labels : 881waveshare_-1.0_0.4
# labels : 882waveshare_-1.0_0.4
# labels : 883waveshare_-1.0_0.4
# labels : 884waveshare_-1.0_0.4
# labels : 885waveshare_0.0_0.4
# labels : 886waveshare_0.0_0.4
# labels : 887waveshare_0.0_0.4
# labels : 888waveshare_0.0_0.4
# labels : 889waveshare_0.0_0.4
# labels : 890waveshare_0.0_0.4
# labels : 891waveshare_0.0_0.4
# labels : 892waveshare_0.0_0.4
# labels : 893waveshare_0.0_0.4
# labels : 894waveshare_0.0_0.4
# labels : 895waveshare_0.0_0.4
# labels : 896waveshare_0.0_0.4
# labels : 897waveshare_0.0_0.4
# labels : 898waveshare_0.0_0.4
# labels : 899waveshare_0.0_0.4
# labels : 900waveshare_0.0_0.4
# labels : 901waveshare_0.0_0.4
# labels : 902waveshare_0.0_0.4
# labels : 903waveshare_0.0_0.4
# labels : 904waveshare_0.0_0.4
# labels : 905waveshare_0.0_0.4
# labels : 906waveshare_0.0_0.4
# labels : 907waveshare_0.0_0.4
# labels : 908waveshare_0.0_0.4
# labels : 909waveshare_0.0_0.4
# labels : 910waveshare_-0.1_0.4
# labels : 911waveshare_-0.1_0.4
# labels : 912waveshare_-1.0_0.4
# labels : 913waveshare_-1.0_0.4
# labels : 914waveshare_-1.0_0.4
# labels : 915waveshare_-1.0_0.4
# labels : 916waveshare_-1.0_0.4
# labels : 917waveshare_-1.0_0.4
# labels : 918waveshare_-1.0_0.4
# labels : 919waveshare_-1.0_0.4
# labels : 920waveshare_-1.0_0.4
# labels : 921waveshare_-1.0_0.4
# labels : 922waveshare_-1.0_0.4
# labels : 923waveshare_-1.0_0.4
# labels : 924waveshare_-1.0_0.4
# labels : 925waveshare_-1.0_0.4
# labels : 926waveshare_-1.0_0.4
# labels : 927waveshare_-1.0_0.4
# labels : 928waveshare_-1.0_0.4
# labels : 929waveshare_-1.0_0.4
# labels : 930waveshare_-1.0_0.4
# labels : 931waveshare_0.0_0.4
# labels : 932waveshare_0.0_0.4
# labels : 933waveshare_0.0_0.4
# labels : 934waveshare_0.0_0.4
# labels : 935waveshare_0.0_0.4
# labels : 936waveshare_0.0_0.4
# labels : 937waveshare_0.0_0.4
# labels : 938waveshare_0.0_0.4
# labels : 939waveshare_-1.0_0.4
# labels : 940waveshare_-1.0_0.4
# labels : 941waveshare_-1.0_0.4
# labels : 942waveshare_-1.0_0.4
# labels : 943waveshare_-1.0_0.4
# labels : 944waveshare_-1.0_0.4
# labels : 945waveshare_-1.0_0.4
# labels : 946waveshare_-1.0_0.4
# labels : 947waveshare_-1.0_0.4
# labels : 948waveshare_-1.0_0.4
# labels : 949waveshare_-1.0_0.4
# labels : 950waveshare_-1.0_0.4
# labels : 951waveshare_-1.0_0.4
# labels : 952waveshare_-1.0_0.4
# labels : 953waveshare_-1.0_0.4
# labels : 954waveshare_-1.0_0.4
# labels : 955waveshare_-1.0_0.4
# labels : 956waveshare_-1.0_0.4
# labels : 957waveshare_-1.0_0.4
# labels : 958waveshare_-1.0_0.4
# labels : 959waveshare_-1.0_0.4
# labels : 960waveshare_-1.0_0.4
# labels : 961waveshare_-1.0_0.4
# labels : 962waveshare_-1.0_0.4
# labels : 963waveshare_-1.0_0.4
# labels : 964waveshare_-1.0_0.4
# labels : 965waveshare_-1.0_0.4
# labels : 966waveshare_-1.0_0.4
# labels : 967waveshare_-0.2_0.4
# labels : 968waveshare_0.0_0.4
# labels : 969waveshare_0.0_0.4
# labels : 970waveshare_0.0_0.4
# labels : 971waveshare_0.0_0.4
# labels : 972waveshare_0.0_0.4
# labels : 973waveshare_0.0_0.4
# labels : 974waveshare_0.0_0.4
# labels : 975waveshare_0.0_0.4
# labels : 976waveshare_0.0_0.4
# labels : 977waveshare_0.0_0.4
# labels : 978waveshare_0.0_0.4
# labels : 979waveshare_-0.6_0.4
# labels : 980waveshare_-0.6_0.4
# labels : 981waveshare_-1.0_0.4
# labels : 982waveshare_-1.0_0.4
# labels : 983waveshare_-0.2_0.4
# labels : 984waveshare_0.0_0.4
# labels : 985waveshare_0.0_0.4
# labels : 986waveshare_0.0_0.4
# labels : 987waveshare_0.0_0.4
# labels : 988waveshare_0.0_0.4
# labels : 989waveshare_0.0_0.4
# labels : 990waveshare_0.0_0.4
# labels : 991waveshare_0.0_0.4
# labels : 992waveshare_0.0_0.4
# labels : 993waveshare_0.0_0.4
# labels : 994waveshare_0.0_0.4
# labels : 995waveshare_0.0_0.4
# labels : 996waveshare_0.0_0.4
# labels : 997waveshare_0.0_0.4
# labels : 998waveshare_0.0_0.4
# labels : 999waveshare_0.0_0.4
# labels : 1000waveshare_-0.1_0.4
# labels : 1001waveshare_-0.1_0.4
# labels : 1002waveshare_-1.0_0.4
# labels : 1003waveshare_-1.0_0.4
# labels : 1004waveshare_-1.0_0.4
# labels : 1005waveshare_-1.0_0.4
# labels : 1006waveshare_-1.0_0.4
# labels : 1007waveshare_-1.0_0.4
# labels : 1008waveshare_-1.0_0.4
# labels : 1009waveshare_-1.0_0.4
# labels : 1010waveshare_-1.0_0.4
# labels : 1011waveshare_-1.0_0.4
# labels : 1012waveshare_-1.0_0.4
# labels : 1013waveshare_-1.0_0.4
# labels : 1014waveshare_-1.0_0.4
# labels : 1015waveshare_-1.0_0.4
# labels : 1016waveshare_-1.0_0.4
# labels : 1017waveshare_-1.0_0.4
# labels : 1018waveshare_-1.0_0.4
# labels : 1019waveshare_-1.0_0.4
# labels : 1020waveshare_-1.0_0.4
# labels : 1021waveshare_-1.0_0.4
# labels : 1022waveshare_-1.0_0.4
# labels : 1023waveshare_-1.0_0.4
# labels : 1024waveshare_-1.0_0.4
# labels : 1025waveshare_-1.0_0.4
# labels : 1026waveshare_-1.0_0.4
# labels : 1027waveshare_-1.0_0.4
# labels : 1028waveshare_-1.0_0.4
# labels : 1029waveshare_-1.0_0.4
# labels : 1030waveshare_-1.0_0.4
# labels : 1031waveshare_-1.0_0.4
# labels : 1032waveshare_-1.0_0.4
# labels : 1033waveshare_-1.0_0.4
# labels : 1034waveshare_-1.0_0.4
# labels : 1035waveshare_-1.0_0.4
# labels : 1036waveshare_-1.0_0.4
# labels : 1037waveshare_-1.0_0.4
# labels : 1038waveshare_-1.0_0.4
# labels : 1039waveshare_0.0_0.4
# labels : 1040waveshare_0.0_0.4
# labels : 1041warehouse_0.0_0.0
# labels : 1042warehouse_0.0_0.2
# labels : 1043warehouse_0.0_0.2
# labels : 1044warehouse_0.0_0.3
# labels : 1045warehouse_0.0_0.3
# labels : 1046warehouse_0.0_0.3
# labels : 1047warehouse_0.0_0.3
# labels : 1048warehouse_0.0_0.4
# labels : 1049warehouse_0.0_0.4
# labels : 1050warehouse_0.0_0.4
# labels : 1051warehouse_0.0_0.4
# labels : 1052warehouse_0.0_0.4
# labels : 1053warehouse_0.0_0.7
# labels : 1054warehouse_0.0_0.7
# labels : 1055warehouse_0.0_0.7
# labels : 1056warehouse_0.0_0.7
# labels : 1057warehouse_0.0_0.7
# labels : 1058warehouse_0.0_0.7
# labels : 1059warehouse_0.0_0.7
# labels : 1060warehouse_0.0_0.7
# labels : 1061warehouse_0.0_0.7
# labels : 1062warehouse_0.0_0.7
# labels : 1063warehouse_0.0_0.7
# labels : 1064warehouse_0.0_0.7
# labels : 1065warehouse_0.0_0.7
# labels : 1066warehouse_0.0_0.7
# labels : 1067warehouse_0.0_0.7
# labels : 1068warehouse_0.0_0.7
# labels : 1069warehouse_0.0_0.7
# labels : 1070warehouse_0.0_0.7
# labels : 1071warehouse_0.0_0.7
# labels : 1072warehouse_0.0_0.7
# labels : 1073warehouse_0.0_0.7
# labels : 1074warehouse_0.0_0.7
# labels : 1075warehouse_0.0_0.7
# labels : 1076warehouse_0.0_0.7
# labels : 1077warehouse_0.0_0.7
# labels : 1078warehouse_0.0_0.7
# labels : 1079warehouse_0.0_0.6
# labels : 1080warehouse_0.0_0.6
# labels : 1081warehouse_0.0_0.6
# labels : 1082warehouse_0.0_0.6
# labels : 1083warehouse_0.0_0.6
# labels : 1084warehouse_0.0_0.6
# labels : 1085warehouse_0.0_0.6
# labels : 1086warehouse_0.0_0.6
# labels : 1087warehouse_0.0_0.6
# labels : 1088warehouse_0.0_0.6
# labels : 1089warehouse_0.0_0.6
# labels : 1090warehouse_0.0_0.6
# labels : 1091warehouse_0.0_0.6
# labels : 1092warehouse_0.0_0.6
# labels : 1093warehouse_0.0_0.6
# labels : 1094warehouse_0.0_0.6
# labels : 1095warehouse_0.0_0.6
# labels : 1096warehouse_0.0_0.6
# labels : 1097warehouse_0.0_0.6
# labels : 1098warehouse_-0.2_0.6
# labels : 1099warehouse_-0.2_0.6
# labels : 1100warehouse_-0.3_0.7
# labels : 1101warehouse_-0.3_0.7
# labels : 1102warehouse_-0.3_0.7
# labels : 1103warehouse_-0.4_0.7
# labels : 1104warehouse_-0.4_0.7
# labels : 1105warehouse_-0.8_0.7
# labels : 1106warehouse_-0.8_0.7
# labels : 1107warehouse_0.0_0.7
# labels : 1108warehouse_0.0_0.6
# labels : 1109warehouse_0.0_0.6
# labels : 1110warehouse_0.0_0.6
# labels : 1111warehouse_0.0_0.6
# labels : 1112warehouse_0.0_0.6
# labels : 1113warehouse_0.0_0.7
# labels : 1114warehouse_0.0_0.7
# labels : 1115warehouse_0.0_0.7
# labels : 1350warehouse_0.0_0.8
# labels : 1351warehouse_0.0_0.8
# labels : 1352warehouse_0.0_0.8
# labels : 1353warehouse_0.0_0.8
# labels : 1354warehouse_0.0_0.8
# labels : 1355warehouse_0.0_0.8
# labels : 1356warehouse_0.0_0.8
# labels : 1357warehouse_0.0_0.8
# labels : 1358warehouse_0.0_0.8
# labels : 1359warehouse_0.0_0.8
# labels : 1360warehouse_0.0_0.8
# labels : 1361warehouse_0.0_0.7
# labels : 1362warehouse_0.0_0.7
# labels : 1363warehouse_0.0_0.7
# labels : 1364warehouse_0.0_0.7
# labels : 1365warehouse_0.0_0.7
# labels : 1366warehouse_0.0_0.7
# labels : 1367warehouse_0.0_0.7
# labels : 1368warehouse_0.0_0.6
# labels : 1369warehouse_0.0_0.1
# labels : 1370warehouse_0.0_0.1
# labels : 1371warehouse_0.0_0.1
# labels : 1372warehouse_0.0_0.1
# labels : 1373warehouse_0.0_0.1
# labels : 1374warehouse_0.0_0.1
# labels : 1375warehouse_0.0_0.1
# labels : 1376warehouse_0.0_0.1
# labels : 1377warehouse_0.0_0.0
# labels : 1378warehouse_0.0_0.0
# labels : 1379warehouse_0.0_0.0
# labels : 1380warehouse_0.0_0.0
# labels : 1381warehouse_0.0_0.0
# labels : 1382warehouse_0.0_0.0
# labels : 1383warehouse_-0.4_0.0
# labels : 1384warehouse_-0.2_0.1
# labels : 1385warehouse_-0.2_0.1
# labels : 1386warehouse_0.0_0.0
# labels : 1387warehouse_0.0_0.1
# labels : 1388warehouse_0.0_0.1
# labels : 1389warehouse_0.0_0.1
# labels : 1390warehouse_0.0_0.1
# labels : 1391warehouse_0.0_0.1
# labels : 1392warehouse_0.0_0.1
# labels : 1393warehouse_0.0_0.1
# labels : 1394warehouse_0.0_0.0
# labels : 1395warehouse_0.0_0.0
# labels : 1396warehouse_0.0_0.1
# labels : 1397warehouse_0.0_0.1
# labels : 1398warehouse_0.0_0.1
# labels : 1399warehouse_-0.3_0.1
# labels : 1400warehouse_-0.3_0.1
# labels : 1401warehouse_-0.3_0.1
# labels : 1402warehouse_-0.3_0.1
# labels : 1403warehouse_-0.3_0.1
# labels : 1404warehouse_-0.3_0.1
# labels : 1405warehouse_-0.4_0.1
# labels : 1406warehouse_-0.4_0.1
# labels : 1407warehouse_-0.4_0.1
# labels : 1408warehouse_-0.4_0.1
# labels : 1409warehouse_-0.4_0.1
# labels : 1410warehouse_-0.3_0.1
# labels : 1411warehouse_-0.3_0.1
# labels : 1412warehouse_-0.3_0.1
# labels : 1413warehouse_0.0_0.1
# labels : 1414warehouse_0.0_0.1
# labels : 1415warehouse_0.0_0.1
# labels : 1416warehouse_0.0_0.1
# labels : 1417warehouse_0.0_0.1
# labels : 1418warehouse_0.0_0.2
# labels : 1419warehouse_0.0_0.2
# labels : 1420warehouse_0.0_0.7
# labels : 1421warehouse_0.0_0.7
# labels : 1422warehouse_0.0_0.7
# labels : 1423warehouse_0.0_0.7
# labels : 1424warehouse_0.0_0.7
# labels : 1425warehouse_0.0_0.7
# labels : 1426warehouse_0.0_0.7
# labels : 1427warehouse_0.0_0.7
# labels : 1428warehouse_0.0_0.7
# labels : 1429warehouse_0.0_0.7
# labels : 1430warehouse_0.0_0.7
# labels : 1431warehouse_0.0_0.7
# labels : 1432warehouse_0.0_0.7
# labels : 1433warehouse_0.0_0.7
# labels : 1434warehouse_0.0_0.7
# labels : 1435warehouse_0.0_0.7
# labels : 1436warehouse_0.0_0.7
# labels : 1437warehouse_0.0_0.7
# labels : 1438warehouse_0.0_0.7
# labels : 1439warehouse_0.0_0.7
# labels : 1440warehouse_0.0_0.7
# labels : 1441warehouse_0.0_0.7
# labels : 1442warehouse_0.0_0.7
# labels : 1443warehouse_0.0_0.7
# labels : 1444warehouse_0.0_0.7
# labels : 1445warehouse_0.0_0.7
# labels : 1446warehouse_0.0_0.7
# labels : 1447warehouse_0.0_0.7
# labels : 1448warehouse_0.0_0.7
# labels : 1449warehouse_0.0_0.7
# labels : 1450warehouse_0.0_0.7
# labels : 1451warehouse_0.0_0.7
# labels : 1452warehouse_0.0_0.7
# labels : 1453warehouse_0.0_0.7
# labels : 1454warehouse_0.0_0.7
# labels : 1455warehouse_0.0_0.7
# labels : 1456warehouse_0.0_0.7
# labels : 1457warehouse_0.0_0.7
# labels : 1458warehouse_0.0_0.7
# labels : 1459warehouse_0.0_0.7
# labels : 1460warehouse_0.0_0.7
# labels : 1461warehouse_0.0_0.7
# labels : 1462warehouse_0.0_0.7
# labels : 1463warehouse_0.0_0.7
# labels : 1464warehouse_0.0_0.7
# labels : 1465warehouse_0.0_0.7
# labels : 1466warehouse_0.0_0.6
# labels : 1467warehouse_0.0_0.6
# labels : 1468warehouse_0.0_0.6
# labels : 1469warehouse_0.0_0.6
# labels : 1470warehouse_0.0_0.6
# labels : 1471warehouse_0.0_0.6
# labels : 1472warehouse_0.0_0.6
# labels : 1473warehouse_0.0_0.6
# labels : 1474warehouse_0.0_0.6
# labels : 1475warehouse_0.0_0.6
# labels : 1476warehouse_0.0_0.6
# labels : 1477warehouse_0.0_0.6
# labels : 1478warehouse_0.0_0.6
# labels : 1479warehouse_0.0_0.4
# labels : 1480warehouse_0.0_0.4
# labels : 1481warehouse_0.0_0.4
# labels : 1482warehouse_0.0_0.2
# labels : 1483warehouse_0.0_0.2
# labels : 1484warehouse_0.0_0.1
# labels : 1485warehouse_0.0_0.1
# labels : 1486warehouse_0.0_0.0
# labels : 1487warehouse_0.0_0.0
# labels : 1488warehouse_0.0_0.0
# labels : 1489warehouse_1.0_0.0
# labels : 1490warehouse_1.0_0.2
# labels : 1491warehouse_1.0_0.2
# labels : 1492warehouse_1.0_0.2
# labels : 1493warehouse_1.0_0.2
# labels : 1494warehouse_1.0_0.2
# labels : 1495warehouse_1.0_0.8
# labels : 1496warehouse_1.0_0.8
# labels : 1497warehouse_1.0_0.7
# labels : 1498warehouse_1.0_0.7
# labels : 1499warehouse_1.0_0.7
# labels : 1500warehouse_1.0_0.7
# labels : 1501warehouse_1.0_0.7
# labels : 1502warehouse_1.0_0.5
# labels : 1503warehouse_1.0_0.5
# labels : 1504warehouse_1.0_0.5
# labels : 1505warehouse_1.0_0.5
# labels : 1506warehouse_1.0_0.5
# labels : 1507warehouse_1.0_0.5
# labels : 1508warehouse_1.0_0.5
# labels : 1509warehouse_1.0_0.5
# labels : 1510warehouse_1.0_0.5
# labels : 1511warehouse_1.0_0.5
# labels : 1512warehouse_1.0_0.5
# labels : 1513warehouse_1.0_0.5
# labels : 1514warehouse_1.0_0.5
# labels : 1515warehouse_0.4_0.5
# labels : 1516warehouse_0.2_0.6
# labels : 1517warehouse_0.2_0.6
# labels : 1518warehouse_0.0_0.6
# labels : 1519warehouse_0.0_0.6
# labels : 1520warehouse_0.0_0.6
# labels : 1521warehouse_0.0_0.6
# labels : 1522warehouse_0.0_0.6
# labels : 1523warehouse_0.0_0.6
# labels : 1524warehouse_0.0_0.6
# labels : 1525warehouse_0.0_0.6
# labels : 1526warehouse_0.0_0.6
# labels : 1527warehouse_0.0_0.6
# labels : 1528warehouse_0.0_0.7
# labels : 1529warehouse_0.0_0.7
# labels : 1530warehouse_0.0_0.7
# labels : 1531warehouse_0.0_0.7
# labels : 1532warehouse_0.0_0.7
# labels : 1533warehouse_0.0_0.7
# labels : 1534warehouse_0.0_0.7
# labels : 1535warehouse_0.0_0.7
# labels : 1536warehouse_0.0_0.7
# labels : 1537warehouse_0.0_0.7
# labels : 1538warehouse_0.0_0.7
# labels : 1539warehouse_0.0_0.7
# labels : 1540warehouse_0.0_0.7
# labels : 1541warehouse_0.0_0.7
# labels : 1542warehouse_0.0_0.8
# labels : 1543warehouse_0.0_0.8
# labels : 1544warehouse_0.0_0.8
# labels : 1545warehouse_0.0_0.8
# labels : 1546warehouse_0.0_0.8
# labels : 1547warehouse_0.0_0.8
# labels : 1548warehouse_0.0_0.7
# labels : 1549warehouse_0.0_0.7
# labels : 1550warehouse_0.0_0.7
# labels : 1551warehouse_0.0_0.7
# labels : 1552warehouse_0.0_0.7
# labels : 1553warehouse_0.0_0.7
# labels : 1554warehouse_0.0_0.7
# labels : 1555warehouse_0.0_0.7
# labels : 1556warehouse_0.3_0.7
# labels : 1557warehouse_0.3_0.7
# labels : 1558warehouse_0.4_0.7
# labels : 1559warehouse_0.4_0.7
# labels : 1560warehouse_0.6_0.7
# labels : 1561warehouse_0.7_0.7
# labels : 1562warehouse_0.7_0.7
# ...
# labels : 5064desert_0.0_0.5
# labels : 5065desert_0.0_0.5
# labels : 5066desert_0.0_0.5
# labels : 5067desert_0.0_0.5
# labels : 5068desert_0.0_0.5
# labels : 5069desert_0.0_0.5
# labels : 5070desert_0.0_0.5
# labels : 5071desert_0.2_0.5
# labels : 5072desert_0.2_0.5
# labels : 5073desert_0.4_0.5
# labels : 5074desert_0.6_0.5
# labels : 5075desert_0.6_0.5
# labels : 5076desert_0.6_0.5
# labels : 5077desert_0.6_0.5
# labels : 5078desert_0.6_0.5
# labels : 5079desert_0.6_0.5
# labels : 5080desert_0.6_0.5
# labels : 5081desert_0.4_0.5
# labels : 5082desert_0.3_0.5
# labels : 5083desert_0.3_0.5
# labels : 5084desert_0.0_0.5
# labels : 5085desert_0.0_0.5
# labels : 5173desert_-0.4_0.3
# labels : 5174desert_-0.3_0.3
# labels : 5175desert_-0.3_0.3
# labels : 5176desert_-0.3_0.3
# labels : 5177desert_-0.3_0.3
# labels : 5178desert_-0.3_0.3
# labels : 5179desert_-0.3_0.3
# labels : 5180desert_-0.3_0.3
# labels : 5181desert_-0.3_0.3
# labels : 5182desert_-0.6_0.3
# labels : 5183desert_-0.6_0.3
# labels : 5184desert_-0.3_0.3
# labels : 5185desert_-0.3_0.3
# labels : 5186desert_-0.2_0.3
# labels : 5187desert_-0.2_0.3
# labels : 5188desert_-0.2_0.3
# labels : 5189desert_0.0_0.3
# labels : 5190desert_0.0_0.3
# labels : 5191desert_0.0_0.3
# labels : 5192desert_0.0_0.3
# labels : 5193desert_0.0_0.3
# labels : 5194desert_0.0_0.3
# labels : 5195desert_0.0_0.3
# labels : 5196desert_0.0_0.3
# labels : 5197desert_0.0_0.3
# labels : 5198desert_0.0_0.3
# labels : 5199desert_0.0_0.3
# labels : 5200desert_0.0_0.3
# labels : 5201desert_0.0_0.3
# labels : 5202desert_0.0_0.3
# labels : 5203desert_0.0_0.3
# labels : 5204desert_0.0_0.3
# labels : 5205desert_0.0_0.3
# labels : 5206desert_0.0_0.3
# labels : 5207desert_0.0_0.3
# labels : 5208desert_0.0_0.3
# labels : 5209desert_0.0_0.3
# labels : 5210desert_0.0_0.3
# labels : 5211desert_0.0_0.3
# labels : 5212desert_0.0_0.3
# labels : 5213desert_0.0_0.3
# labels : 5214desert_0.0_0.3
# labels : 5215desert_0.0_0.3
# labels : 5216desert_-0.2_0.3
# labels : 5217desert_-0.2_0.3
# labels : 5218desert_0.0_0.3
# labels : 5219desert_0.0_0.3
# labels : 5220desert_0.0_0.3
# labels : 5221desert_0.0_0.3
# labels : 5222desert_0.0_0.3
# labels : 5223desert_0.0_0.3
# labels : 5224desert_0.0_0.3
# labels : 5225desert_0.0_0.3
# labels : 5226desert_-0.3_0.3
# labels : 5227desert_-0.4_0.3
# labels : 5228desert_-0.4_0.3
# labels : 5229desert_-0.3_0.3
# labels : 5230desert_-0.3_0.3
# labels : 5231desert_-0.3_0.3
# labels : 5232desert_-0.3_0.3
# labels : 5233desert_-0.3_0.3
# labels : 5234desert_-0.3_0.3
# labels : 5235desert_0.0_0.3
# labels : 5236desert_0.0_0.3
# labels : 5237desert_0.0_0.3
# labels : 5238desert_0.0_0.3
# labels : 5239desert_0.0_0.3
# labels : 5240desert_0.0_0.3
# labels : 5241desert_0.0_0.3
# labels : 5242desert_0.0_0.4
# labels : 5243desert_0.0_0.4
# labels : 5244desert_0.0_0.4
# labels : 5245desert_0.0_0.4
# labels : 5246desert_0.0_0.4
# labels : 5247desert_0.0_0.4
# labels : 5248desert_0.0_0.5
# labels : 5249desert_0.0_0.5
# labels : 5250desert_0.0_0.5
# labels : 5251desert_0.0_0.5
# labels : 5252desert_0.0_0.6
# labels : 5253desert_0.0_0.6
# labels : 5254desert_0.0_0.6
# labels : 5255desert_0.0_0.6
# labels : 5256desert_0.0_0.6
# labels : 5257desert_0.0_0.6
# labels : 5518desert_0.3_0.6
# labels : 5519desert_0.5_0.6
# labels : 5520desert_0.5_0.6
# labels : 5521desert_0.0_0.5
# labels : 5522desert_0.0_0.5
# labels : 5523desert_0.0_0.5
# labels : 5524desert_0.0_0.5
# labels : 5525desert_0.0_0.5
# labels : 5526desert_0.0_0.5
# labels : 5527desert_0.0_0.5
# labels : 5528desert_0.0_0.5
# labels : 5529desert_0.0_0.5
# labels : 5530desert_0.0_0.5
# labels : 5531desert_0.0_0.5
# labels : 5532desert_0.0_0.5
# labels : 5533desert_0.0_0.5
# labels : 5534desert_0.0_0.5
# labels : 5535desert_0.0_0.5
# labels : 5536desert_0.0_0.5
# labels : 5537desert_0.0_0.5
# labels : 5538desert_0.0_0.5
# labels : 5539desert_0.0_0.5
# labels : 5540desert_-0.3_0.5
# labels : 5541desert_-0.3_0.5
# labels : 5542desert_-0.3_0.5
# labels : 5543desert_-0.3_0.5
# labels : 5544desert_-0.2_0.5
# labels : 5545desert_0.0_0.5
# labels : 5546desert_0.0_0.5
# labels : 5547desert_0.0_0.5
# labels : 5548desert_0.0_0.5
# labels : 5549desert_0.0_0.5
# labels : 5550desert_0.0_0.5
# labels : 5551desert_0.0_0.5
# labels : 5552desert_0.0_0.5
# labels : 5553desert_0.0_0.5
# labels : 5554desert_0.0_0.5
# labels : 5555desert_0.0_0.5
# labels : 5556desert_0.0_0.5
# labels : 5557desert_0.0_0.5
# labels : 5558desert_0.0_0.5
# labels : 5559desert_0.0_0.5
# labels : 5560desert_0.0_0.5
# labels : 5561desert_0.0_0.5
# labels : 5562desert_0.0_0.5
# labels : 5563desert_0.0_0.5
# labels : 5564desert_0.0_0.5
# labels : 5565desert_0.0_0.5
# labels : 5566desert_0.0_0.5
# labels : 5567desert_0.0_0.5
# labels : 5568desert_0.0_0.5
# labels : 5569desert_0.0_0.5
# labels : 5570desert_0.0_0.5
# labels : 5571desert_-0.2_0.5
# labels : 5572desert_-0.2_0.5
# labels : 5573desert_-0.4_0.5
# labels : 5574desert_-0.6_0.5
# labels : 5575desert_-0.6_0.5
# labels : 5576desert_-0.6_0.5
# labels : 5577desert_-0.6_0.5
# labels : 5578desert_-0.6_0.5
# labels : 5579desert_-0.6_0.5
# labels : 5580desert_-0.6_0.5
# labels : 5581desert_-0.6_0.5
# labels : 5582desert_-0.8_0.5
# labels : 5583desert_-0.8_0.5
# labels : 5584desert_-0.9_0.5
# labels : 5585desert_-0.9_0.5
# labels : 5586desert_-0.9_0.5
# labels : 5587desert_-1.0_0.5
# labels : 5588desert_-1.0_0.5
# labels : 5589desert_-1.0_0.5
# labels : 5590desert_-1.0_0.5
# labels : 5591desert_-1.0_0.5
# labels : 5592desert_-1.0_0.5
# labels : 5593desert_-1.0_0.5
# labels : 5594desert_-1.0_0.5
# labels : 5595desert_-1.0_0.5
# labels : 5596desert_-1.0_0.5
# labels : 5597desert_-1.0_0.5
# labels : 5598desert_-1.0_0.5
# labels : 5599desert_-1.0_0.5
# labels : 5600desert_-1.0_0.5
# labels : 5601desert_-1.0_0.5
# labels : 5602desert_-1.0_0.5
# labels : 5603desert_-1.0_0.5
# labels : 5604desert_-1.0_0.5
# labels : 5605desert_-1.0_0.5
# labels : 5606desert_-1.0_0.5
# labels : 5607desert_-1.0_0.5
# labels : 5608desert_-1.0_0.5
# labels : 5609desert_-1.0_0.5
# labels : 5610desert_-1.0_0.5
# labels : 5611desert_-1.0_0.5
# labels : 5612desert_-0.4_0.5
# labels : 5613desert_-0.4_0.5
# labels : 5614desert_0.0_0.5
# labels : 5615desert_0.0_0.5
# labels : 5616desert_0.0_0.5
# labels : 5617desert_0.0_0.5
# labels : 5618desert_0.0_0.5
# labels : 5619desert_0.0_0.5
# labels : 5620desert_0.0_0.5
# labels : 5621desert_0.0_0.5
# labels : 5622desert_0.0_0.5
# labels : 5623desert_0.0_0.5
# labels : 5624desert_0.0_0.5
# labels : 5625desert_0.0_0.5
# labels : 5626desert_0.0_0.5
# labels : 5627desert_0.0_0.2
# labels : 5628desert_0.0_0.2
# labels : 5629desert_0.0_0.2
# labels : 5630desert_0.0_0.2
# labels : 5631desert_0.0_0.2

# %%
liste_labels[0]
# Out:
# '1waveshare_0.0_0.0'

# %%
liste_labels_waveshare = []
liste_labels_warehouse = []
liste_labels_generated = []
liste_labels_desert = []

for i in liste_labels:
    if "waveshare" in i:
        liste_labels_waveshare.append(i)

for i in liste_labels:
    if "warehouse" in i:
        liste_labels_warehouse.append(i)
        
for i in liste_labels:
    if "generated" in i:
        liste_labels_generated.append(i)
        
for i in liste_labels:
    if "desert" in i:
        liste_labels_desert.append(i)

liste_labels_desert[0]
# Out:
# '4353desert_0.0_0.1'

# %%
images_sigma = 'C:/Users/afougere/Git/e1/data_analysis/data/images_data/images/'

l_circuit = ['warehouse/', 'generated/', 'desert/']

# %% [markdown]
# from zipfile import ZipFile
#
# # spécifiant le nom du fichier zip
# file = "waveshare.zip"
#
# # ouvrir le fichier zip en mode lecture
# with ZipFile(images_sigma + file, 'r') as zip:
#     # afficher tout le contenu du fichier zip
#     zip.printdir()
#
#     # extraire tous les fichiers
#     print('extraction...')
#     zip.extractall(path_images_waveshare)
#     print('Terminé!')
#
#
# file = "warehouse.zip"
#
# # ouvrir le fichier zip en mode lecture
# with ZipFile(images_sigma + file, 'r') as zip:
#     # afficher tout le contenu du fichier zip
#     zip.printdir()
#
#     # extraire tous les fichiers
#     print('extraction...')
#     zip.extractall(images_sigma)
#     print('Terminé!')
#
#
# file = "generated.zip"
#
# # ouvrir le fichier zip en mode lecture
# with ZipFile(images_sigma + file, 'r') as zip:
#     # afficher tout le contenu du fichier zip
#     zip.printdir()
#
#     # extraire tous les fichiers
#     print('extraction...')
#     zip.extractall(images_sigma)
#     print('Terminé!')

# %%
#liste_image_waveshare = [f for f in listdir(path_images_waveshare) if isfile(join(path_images_waveshare, f))]
liste_image_warehouse = [f for f in listdir("../data/images_data/images/circuits/warehouse") if isfile(join("../data/images_data/images/circuits/warehouse", f))]
liste_image_generated = [f for f in listdir("../data/images_data/images/circuits/generated") if isfile(join("../data/images_data/images/circuits/generated", f))]
liste_image_desert = [f for f in listdir("../data/images_data/images/circuits/desert") if isfile(join("../data/images_data/images/circuits/desert", f))]

len(liste_image_generated)
# Out:
# 1504

# %%
#liste_pict_waveshare = []
liste_pict_warehouse = []
liste_pict_generated = []
liste_pict_desert = []

#for image in liste_image_waveshare:
        
    #url_image = os.path.join(path_images_waveshare, image)
    #im_w = Image.open(url_image)
    #image = np.asarray(im_w)
    #liste_pict_waveshare.append(image)
    
for image in liste_image_warehouse:
        
    url_image = os.path.join("../data/images_data/images/circuits/warehouse", image)
    im_t = Image.open(url_image)
    image = np.asarray(im_t)
    liste_pict_warehouse.append(image)
    
    
for image in liste_image_generated:
        
    url_image = os.path.join("../data/images_data/images/circuits/generated", image)
    im_a = Image.open(url_image)
    image = np.asarray(im_a)
    liste_pict_generated.append(image)
    
for image in liste_image_desert:
        
    url_image = os.path.join("../data/images_data/images/circuits/desert", image)
    im_a = Image.open(url_image)
    image = np.asarray(im_a)
    liste_pict_desert.append(image)
    
liste_pict_desert[0]
# Out:
# array([[[ 97, 125, 162],
#         [ 97, 125, 162],
#         [ 96, 124, 161],
#         ...,
#         [ 93, 118, 158],
#         [ 94, 119, 159],
#         [ 94, 119, 159]],
#
#        [[ 97, 125, 162],
#         [ 97, 125, 162],
#         [ 97, 125, 162],
#         ...,
#         [ 94, 119, 159],
#         [ 94, 119, 159],
#         [ 94, 119, 159]],
#
#        [[ 98, 126, 163],
#         [ 98, 126, 163],
#         [ 98, 126, 163],
#         ...,
#         [ 95, 120, 160],
#         [ 95, 120, 160],
#         [ 95, 120, 160]],
#
#        ...,
#
#        [[105, 112, 120],
#         [112, 119, 127],
#         [119, 126, 134],
#         ...,
#         [251, 255, 255],
#         [229, 233, 236],
#         [204, 208, 211]],
#
#        [[100, 107, 115],
#         [106, 113, 121],
#         [117, 124, 132],
#         ...,
#         [252, 255, 255],
#         [246, 250, 253],
#         [237, 241, 244]],
#
#        [[109, 116, 124],
#         [113, 120, 128],
#         [122, 129, 137],
#         ...,
#         [250, 254, 255],
#         [251, 255, 255],
#         [252, 255, 255]]], dtype=uint8)

# %%
#x = liste_labels_waveshare
#y = liste_pict_waveshare

a = liste_labels_warehouse
b = liste_pict_warehouse

c = liste_labels_generated
d = liste_pict_generated

e = liste_labels_desert
f = liste_pict_desert

#dico_label_waveshare = {x:y for x,y in zip(x, y)}
dico_label_warehouse = {a:b for a,b in zip(a, b)}
dico_label_generated = {c:d for c,d in zip(c, d)}
dico_label_desert = {e:f for e,f in zip(e, f)}

# %%
#for k, v in dico_label_waveshare.items():
        
        #print(image_sortie)
        #Image.fromarray(v).save(path_images_waveshare + "label_waveshare/{}.jpg".format(k))
        
for k, v in dico_label_warehouse.items():
        
        #print(image_sortie)
        Image.fromarray(v).save("../data/images_data/images/circuits/warehouse/label_warehouse/{}.jpg".format(k))
        
for k, v in dico_label_generated.items():
        
        #print(image_sortie)
        Image.fromarray(v).save("../data/images_data/images/circuits/generated/label_generated/{}.jpg".format(k))
        
for k, v in dico_label_desert.items():
        
        #print(image_sortie)
        Image.fromarray(v).save("../data/images_data/images/circuits/desert/label_desert/{}.jpg".format(k))
